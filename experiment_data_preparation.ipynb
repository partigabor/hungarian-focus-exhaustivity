# %% [markdown]
# # Prepare Experimental Data

# %%
import pandas as pd

# %% [markdown]
# ## Practice

# %%
# Read in the practice sheet in experiment_stimuli.xlsx into a pandas df
df = pd.read_excel("experiment_stimuli.xlsx", sheet_name="practice") 

# Make sure that item and no are integers
df['exp'] = pd.to_numeric(df['exp'], errors='coerce').astype('Int64')
df['item'] = pd.to_numeric(df['item'], errors='coerce').astype('Int64')
df['no'] = pd.to_numeric(df['no'], errors='coerce').astype('Int64')

# Drop rows where 'item' is empty or not an integer
df = df[pd.to_numeric(df["item"], errors="coerce").notna()]

# Drop these columns: image_pair_left	image_pair_right	vpx	definite	uncountable	remark
df = df.drop(columns=['image_pair_left', 'image_pair_right', 'vpx', 'definite', 'uncountable', 'remark'], errors='ignore')

# If 'cb' column is 'y', then switch the values of the left and right column.
df.loc[df['cb'] == 'y', ['left', 'right']] = df.loc[df['cb'] == 'y', ['right', 'left']].values

# Randomize the order of the rows in a reproducible way
# df = df.sample(frac=1, random_state=1349).reset_index(drop=True)

# Reset index
df = df.reset_index(drop=True)

# Save to CSV
csv_file = "practice.csv"
df.to_csv(csv_file, index=False)

print(f"Filtered data saved to {csv_file}!")
df
# Out:
# Filtered data saved to practice.csv!
#     no  item   exp condition  group cb     r1                r2       r3  \
# 0  990     1  <NA>  practice    NaN  n     Ez  egy példamondat,   kérlek
# 1  991     2  <NA>  practice    NaN  y  Ez is   csak gyakorlás,   kérlek
# 2  992     3  <NA>  practice    NaN  n    Itt             pedig  válaszd
#
#             r4       r5          r6      r7 left right  \
# 0      válaszd     majd  az A betűs  képet.    A     B
# 1         majd  válaszd   a C betűs  képet.    D     C
# 2  azt a képet  amelyik    balodalt    van.    E     F
#
#                     question target
# 0                        NaN      A
# 1                        NaN      C
# 2  Melyik van a bal oldalon?      E

# %% [markdown]
# ## Live Experiment

# %%
# Read in experiment.xlsx into a pandas df
import pandas as pd

df = pd.read_excel("experiment_stimuli.xlsx", sheet_name="main")

# Make sure that item and no are integers
df['exp'] = pd.to_numeric(df['exp'], errors='coerce').astype('Int64')
df['item'] = pd.to_numeric(df['item'], errors='coerce').astype('Int64')
df['no'] = pd.to_numeric(df['no'], errors='coerce').astype('Int64')

# Drop rows where 'item' is empty or not an integer
df = df[pd.to_numeric(df["item"], errors="coerce").notna()]

# Drop these columns: image_pair_left	image_pair_right	vpx	definite	uncountable	remark
df = df.drop(columns=['image_pair_left', 'image_pair_right', 'vpx', 'definite', 'uncountable', 'remark'], errors='ignore')

# If 'cb' column is 'y', then switch the values of the left and right column.
df.loc[df['cb'] == 'y', ['left', 'right']] = df.loc[df['cb'] == 'y', ['right', 'left']].values
df
# Out:
#       no  item   exp        condition group cb         r1              r2  \
# 0      1     1     1       exhaustive     a  n        Ami  a gyümölcsöket
# 3      2     1     1       unmodified     b  y        Ami  a gyümölcsöket
# 6      3     1     1      contrastive     c  n     Tegnap          reggel
# 9      4     2     1       exhaustive     b  y        Ami  az írószereket
# 12     5     2     1       unmodified     c  n        Ami  az írószereket
# ..   ...   ...   ...              ...   ... ..        ...             ...
# 351  118    35  <NA>  attention-check     b  y         Ha  figyelsz arra,
# 354  119    35  <NA>  attention-check     c  n         Ha  figyelsz arra,
# 357  120    36  <NA>  attention-check     a  y  Figyelsz?        Ha igen,
# 360  121    36  <NA>  attention-check     b  n  Figyelsz?        Ha igen,
# 363  122    36  <NA>  attention-check     c  y  Figyelsz?        Ha igen,
#
#           r3        r4       r5           r6          r7     left    right  \
# 0    illeti,      Anna     csak   egy banánt      evett.       1a       1b
# 3    illeti,      Anna   tegnap   egy banánt      evett.       1b       1a
# 6       Anna    többek   között   egy banánt      evett.       1a       1b
# 9    illeti,  a kisfiú     csak  egy ceruzát     kapott.       2b       2a
# 12   illeti,  a kisfiú   tegnap  egy ceruzát     kapott.       2a       2b
# ..       ...       ...      ...          ...         ...      ...      ...
# 351     amit   olvasol  válaszd         majd  a madarat.   tigris  pelikán
# 354     amit   olvasol  válaszd         majd  a madarat.  pelikán   tigris
# 357    akkor    melyik   a nap        utolsó   étkezése?  reggeli  vacsora
# 360    akkor    melyik   a nap        utolsó   étkezése?  vacsora  reggeli
# 363    akkor    melyik   a nap        utolsó   étkezése?  reggeli  vacsora
#
#                 question   target
# 0                    NaN       1a
# 3                    NaN      NaN
# 6                    NaN       1b
# 9                    NaN       2a
# 12                   NaN      NaN
# ..                   ...      ...
# 351  Melyiket választod?  pelikán
# 354  Melyiket választod?  pelikán
# 357  Melyiket választod?  vacsora
# 360  Melyiket választod?  vacsora
# 363  Melyiket választod?  vacsora
#
# [122 rows x 17 columns]

# %%
# Randomize the order of the rows in a reproducible way
# df = df.sample(frac=1, random_state=1349).reset_index(drop=True)

# Ensure no two consecutive rows have the same value in the 'condition' column.
import heapq
import random

def shuffle_no_adjacent(df, col='condition', random_state=42, max_fallback_attempts=200):
    rng = random.Random(random_state)

    # Build groups of row indices per condition
    groups = {}
    for idx, cond in df[col].astype(str).items():
        groups.setdefault(cond, []).append(idx)

    # Shuffle within each condition for randomness
    for lst in groups.values():
        rng.shuffle(lst)

    # Quick impossibility check: a condition with too many items cannot be arranged
    counts = {k: len(v) for k, v in groups.items()}
    total = sum(counts.values())
    if any(c > (total - c) + 1 for c in counts.values()):
        # fallback: try repeated random shuffles until success (rare)
        for attempt in range(max_fallback_attempts):
            shuffled = df.sample(frac=1, random_state=random_state + attempt).reset_index(drop=True)
            if (shuffled[col].shift() != shuffled[col]).all():
                return shuffled
        raise ValueError("Cannot arrange rows to avoid adjacent identical conditions (too imbalanced).")

    # Shuffle initial heap order for more randomness
    heap_items = [(-len(lst), cond) for cond, lst in groups.items()]
    rng.shuffle(heap_items)
    heapq.heapify(heap_items)
    heap = heap_items

    result_indices = []
    prev_cond = None

    while heap:
        # Find all heap entries not equal to prev_cond
        candidates = [entry for entry in heap if entry[1] != prev_cond]
        if not candidates:
            # fallback: try repeated random shuffles until success
            for attempt in range(max_fallback_attempts):
                shuffled = df.sample(frac=1, random_state=random_state + attempt).reset_index(drop=True)
                if (shuffled[col].shift() != shuffled[col]).all():
                    return shuffled
            raise ValueError("Failed to build non-adjacent ordering (unexpected).")
        # Randomly select among candidates
        chosen_entry = rng.choice(candidates)
        heap.remove(chosen_entry)
        cnt, cond = chosen_entry
        cnt = -cnt
        # take one from cond
        result_indices.append(groups[cond].pop())
        cnt -= 1
        if cnt > 0:
            heapq.heappush(heap, (-cnt, cond))
        prev_cond = cond

    ordered_df = df.loc[result_indices].reset_index(drop=True)
    return ordered_df

# Replace the previous simple shuffle with the constrained shuffle
df = shuffle_no_adjacent(df, col='condition', random_state=42)
df
# Out:
#       no  item   exp         condition group cb               r1  \
# 0     74    23     2  other-directed-x     b  y  A biztonsági őr
# 1     65    21     2   self-directed-x     b  n         Az orvos
# 2     39    13     1       contrastive     c  n          Múltkor
# 3    114    34  <NA>   attention-check     a  y      Ez a mondat
# 4     12     4     1       contrastive     c  y           Tavaly
# ..   ...   ...   ...               ...   ... ..              ...
# 117   45    15     1       contrastive     b  n            Éjjel
# 118   44    15     1        unmodified     a  y              Ami
# 119   84    26     2    other-directed     c  y         A pilóta
# 120   35    12     1        unmodified     a  n              Ami
# 121   88    27     2    other-directed     a  y         A katona
#
#                       r2           r3            r4           r5  \
# 0                 tudta,         hogy      a rendőr      ellopta
# 1              hallotta,         hogy     a tűzoltó    megmondta
# 2        az állatkertben   a gyerekek        többek       között
# 3    egy figyelmi próba,          itt       válaszd     a kisebb
# 4               ilyenkor  a katonaság        többek       között
# ..                   ...          ...           ...          ...
# 117           a szigeten      a kalóz        többek       között
# 118          a kincseket      illeti,       a kalóz        éjjel
# 119           úgy vélte,         hogy  a professzor  irigykedett
# 120             a kertet      illeti,       a férfi      tíz éve
# 121               látta,         hogy  a kórboncnok      lenézte
#
#                 r6                r7        left          right  \
# 0              NaN      a fizetését.      rendőr  biztonsági őr
# 1              NaN     a véleményét.       orvos        tűzoltó
# 2     az elefántot       nézték meg.         13a            13b
# 3              NaN          állatot.      hangya     jegesmedve
# 4    a helikoptert        tesztelte.          4b             4a
# ..             ...               ...         ...            ...
# 117     az aranyat      találta meg.         15a            15b
# 118     az aranyat      találta meg.         15b            15a
# 119            NaN  a kapcsolataira.  professzor         pilóta
# 120   egy fenyőfát      ültetett el.         12a            12b
# 121            NaN       a munkáját.  kórboncnok         katona
#
#                             question         target
# 0        Kinek a fizetésről van szó?  biztonsági őr
# 1      Kinek a véleményéről van szó?        tűzoltó
# 2                                NaN            13b
# 3                                NaN         hangya
# 4                                NaN             4b
# ..                               ...            ...
# 117                              NaN            15b
# 118                              NaN            NaN
# 119  Kinek a kapcsolatairól van szó?         pilóta
# 120                              NaN            NaN
# 121     Kinek a munkájáról van  szó?         katona
#
# [122 rows x 17 columns]

# %%
print(df['condition'].value_counts())
# Out:
# condition
# contrastive         18
# exhaustive          18
# unmodified          18
# other-directed-x    14
# other-directed      14
# self-directed-x     14
# self-directed       14
# attention-check     12
# Name: count, dtype: int64

# %%
# Show me only rows of group a
df_a = df[df['group'] == 'a'].reset_index(drop=True)
df_a = shuffle_no_adjacent(df_a, col='condition', random_state=345)
df_b = df[df['group'] == 'b'].reset_index(drop=True)
df_b = shuffle_no_adjacent(df_b, col='condition', random_state=678)
df_c = df[df['group'] == 'c'].reset_index(drop=True)
df_c = shuffle_no_adjacent(df_c, col='condition', random_state=129)

# Concatenate the three groups back together
df = pd.concat([df_a, df_b, df_c]).reset_index(drop=True)

# Drop rows where group is "a"
df = df[df['group'] != 'a']

# Reset index
df = df.reset_index(drop=True)

# Save to CSV
csv_file = "experiment_data.csv"
df.to_csv(csv_file, index=False)

print(f"Filtered data saved to {csv_file}!")
df
# Out:
# Filtered data saved to experiment_data.csv!
#     no  item  exp        condition group cb         r1                  r2  \
# 0   38    13    1       unmodified     b  y        Ami        az állatokat
# 1   13     5    1       exhaustive     b  n        Ami      a süteményeket
# 2   18     6    1      contrastive     b  y  Hallottam                hogy
# 3   11     4    1       unmodified     b  n        Ami  a harci eszközöket
# 4   45    15    1      contrastive     b  n      Éjjel          a szigeten
# ..  ..   ...  ...              ...   ... ..        ...                 ...
# 76  16     6    1       exhaustive     c  y        Ami         a virágokat
# 77  32    11    1       unmodified     c  y        Ami        a járműveket
# 78  81    25    2  self-directed-x     c  n    A tudós       számított rá,
# 79  48    16    1      contrastive     c  y         Ma              ebédre
# 80  52    18    1       exhaustive     c  y        Ami            a táncot
#
#          r3           r4          r5             r6             r7   left  \
# 0   illeti,   a gyerekek     múltkor   az elefántot    nézték meg.    13b
# 1   illeti,           én        csak       a fánkot      sütöttem.     5a
# 2       Éva       többek      között     a tulipánt       szereti.     6b
# 3   illeti,  a katonaság      tavaly  a helikoptert     tesztelte.     4a
# 4   a kalóz       többek      között     az aranyat   találta meg.    15a
# ..      ...          ...         ...            ...            ...    ...
# 76  illeti,          Éva        csak     a tulipánt       szereti.     6b
# 77  illeti,   a turisták  a hétvégén    egy robogót   béreltek ki.    11b
# 78     hogy    az ügyész  felolvassa            NaN  a vallomását.  tudós
# 79  a nagyi       többek      között         levest    tálalt fel.    16b
# 80  illeti,        Péter        csak          Marit     kérte fel.    18b
#
#      right                       question  target
# 0      13a                            NaN     NaN
# 1       5b                            NaN      5a
# 2       6a                            NaN      6b
# 3       4b                            NaN     NaN
# 4      15b                            NaN     15b
# ..     ...                            ...     ...
# 76      6a                            NaN      6a
# 77     11a                            NaN     NaN
# 78  ügyész  Kinek a vallomásáról van szó?  ügyész
# 79     16a                            NaN     16b
# 80     18a                            NaN     18a
#
# [81 rows x 17 columns]

# %%
# Visualize for me that in group a, where are the attention checks in the row order compared to other conditions
import matplotlib.pyplot as plt
import numpy as np

# Normalize condition strings to avoid mismatches (strip, lower, replace spaces/hyphens with underscore)
df_a = df_a.copy()
df_a['condition_norm'] = (
    df_a['condition'].astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r'[\s-]+', '_', regex=True)
)

# Debug: show unique normalized conditions so we can see why an exact match may have failed
print("Unique conditions (normalized):", sorted(df_a['condition_norm'].unique()))

plt.figure(figsize=(12, 6))
# Convert normalized condition to categorical codes so we can plot on a numeric y-axis with meaningful labels
conds = pd.Categorical(df_a['condition_norm'])
y_vals = conds.codes

# styles: attention checks stand out (big red markers with black edge); others are small light-gray markers
is_ac = df_a['condition_norm'] == 'attention_check'
colors = np.where(is_ac, 'red', 'lightgray')
sizes = np.where(is_ac, 140, 30)
edgecolors = np.where(is_ac, 'black', 'none')

plt.scatter(df_a.index, y_vals, c=colors, s=sizes, alpha=0.9, edgecolors=edgecolors, linewidths=0.7)

# Annotate attention checks with their row index for quick identification
ac_indices = df_a.index[is_ac]
for idx in ac_indices:
    pos = df_a.index.get_loc(idx)
    plt.annotate(str(idx), (idx, y_vals[pos]), xytext=(0, 8), textcoords='offset points', ha='center', fontsize=8, color='darkred')

# Y ticks show the condition names
plt.yticks(np.arange(len(conds.categories)), conds.categories)
plt.xlabel('Row Index (within Group A ordering)')
plt.title('Attention checks (red) vs other conditions (gray) — Group A')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.savefig("attention_checks_group_a.png")
plt.show()
# Out:
# Unique conditions (normalized): ['attention_check', 'contrastive', 'exhaustive', 'other_directed', 'other_directed_x', 'self_directed', 'self_directed_x', 'unmodified']

# %%
# Visualize for me that in group a, where are the attention checks in the row order compared to other conditions
import matplotlib.pyplot as plt
import numpy as np

# Normalize condition strings to avoid mismatches (strip, lower, replace spaces/hyphens with underscore)
df_b = df_b.copy()
df_b['condition_norm'] = (
    df_b['condition'].astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r'[\s-]+', '_', regex=True)
)

# Debug: show unique normalized conditions so we can see why an exact match may have failed
print("Unique conditions (normalized):", sorted(df_b['condition_norm'].unique()))

plt.figure(figsize=(12, 6))
# Convert normalized condition to categorical codes so we can plot on a numeric y-axis with meaningful labels
conds = pd.Categorical(df_b['condition_norm'])
y_vals = conds.codes

# styles: attention checks stand out (big red markers with black edge); others are small light-gray markers
is_ac = df_b['condition_norm'] == 'attention_check'
colors = np.where(is_ac, 'red', 'lightgray')
sizes = np.where(is_ac, 140, 30)
edgecolors = np.where(is_ac, 'black', 'none')

plt.scatter(df_b.index, y_vals, c=colors, s=sizes, alpha=0.9, edgecolors=edgecolors, linewidths=0.7)

# Annotate attention checks with their row index for quick identification
ac_indices = df_b.index[is_ac]
for idx in ac_indices:
    pos = df_b.index.get_loc(idx)
    plt.annotate(str(idx), (idx, y_vals[pos]), xytext=(0, 8), textcoords='offset points', ha='center', fontsize=8, color='darkred')

# Y ticks show the condition names
plt.yticks(np.arange(len(conds.categories)), conds.categories)
plt.xlabel('Row Index (within Group B ordering)')
plt.title('Attention checks (red) vs other conditions (gray) — Group B')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.savefig("attention_checks_group_b.png")
plt.show()
# Out:
# Unique conditions (normalized): ['attention_check', 'contrastive', 'exhaustive', 'other_directed', 'other_directed_x', 'self_directed', 'self_directed_x', 'unmodified']

# %%
# Visualize for me that in group a, where are the attention checks in the row order compared to other conditions
import matplotlib.pyplot as plt
import numpy as np

# Normalize condition strings to avoid mismatches (strip, lower, replace spaces/hyphens with underscore)
df_c = df_c.copy()
df_c['condition_norm'] = (
    df_c['condition'].astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r'[\s-]+', '_', regex=True)
)

# Debug: show unique normalized conditions so we can see why an exact match may have failed
print("Unique conditions (normalized):", sorted(df_c['condition_norm'].unique()))

plt.figure(figsize=(12, 6))
# Convert normalized condition to categorical codes so we can plot on a numeric y-axis with meaningful labels
conds = pd.Categorical(df_c['condition_norm'])
y_vals = conds.codes

# styles: attention checks stand out (big red markers with black edge); others are small light-gray markers
is_ac = df_c['condition_norm'] == 'attention_check'
colors = np.where(is_ac, 'red', 'lightgray')
sizes = np.where(is_ac, 140, 30)
edgecolors = np.where(is_ac, 'black', 'none')

plt.scatter(df_c.index, y_vals, c=colors, s=sizes, alpha=0.9, edgecolors=edgecolors, linewidths=0.7)

# Annotate attention checks with their row index for quick identification
ac_indices = df_c.index[is_ac]
for idx in ac_indices:
    pos = df_c.index.get_loc(idx)
    plt.annotate(str(idx), (idx, y_vals[pos]), xytext=(0, 8), textcoords='offset points', ha='center', fontsize=8, color='darkred')

# Y ticks show the condition names
plt.yticks(np.arange(len(conds.categories)), conds.categories)
plt.xlabel('Row Index (within Group C ordering)')
plt.title('Attention checks (red) vs other conditions (gray) — Group C')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.savefig("attention_checks_group_c.png")
plt.show()
# Out:
# Unique conditions (normalized): ['attention_check', 'contrastive', 'exhaustive', 'other_directed', 'other_directed_x', 'self_directed', 'self_directed_x', 'unmodified']
